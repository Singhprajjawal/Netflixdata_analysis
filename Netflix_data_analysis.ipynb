# %%
import pandas as pd

# %% [markdown]
# # Reading the Dataset

# %%
df=pd.read_csv(r"C:\Users\Prajwal Singh\Downloads\netflix\8. Netflix Dataset.csv")
df
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                    07:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# # Head and Tail

# %%
 df.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description
# 0  In a future where the elite inhabit an island ...
# ...

# %%
df.tail(3)
# Out:
#      Show_Id Category                                    Title  Director  \
# 7786   s7785    Movie                        Zulu Man in Japan       NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts       NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  Sam Dunn
#
#                             Cast                                Country  \
# 7786                     Nasty C                                    NaN
# 7787  Adriano Zumbo, Rachel Khoo                              Australia
# 7788                         NaN  United Kingdom, Canada, United States
#
#             Release_Date Rating  Duration  \
# 7786  September 25, 2020  TV-MA    44 min
# 7787    October 31, 2020  TV-PG  1 Season
# 7788       March 1, 2020  TV-MA    90 min
#
#                                                    Type  \
# 7786  Documentaries, International Movies, Music & M...
# 7787                 International TV Shows, Reality TV
# ...

# %% [markdown]
# # shape

# %%
df.shape
# Out:
# (7789, 11)

# %%
df.size
# Out:
# 85679

# %% [markdown]
# # All Columns

# %%
df.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %% [markdown]
# # Datatype of Columns

# %%
df.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %% [markdown]
# # Getting duplicate records

# %%
df[df.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %% [markdown]
# # dropping duplicate records

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# # Checking the Null values

# %%
df.isnull()
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %% [markdown]
# # checking the sum of all null values with respect to columns

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot: >

# %% [markdown]
# # finding records where  house of card in title

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # OR

# %%
df[df['Title'].str.contains('House of Cards')]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# # changing the datatype of column

# %%
df['Release_Date']=pd.to_datetime(df['Release_Date'])

# %%
df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# dtype: object

# %% [markdown]
# # Count of year

# %%
df['Release_Date'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2008.0       2
# 2009.0       2
# 2010.0       1
# Name: Release_Date, dtype: int64

# %%
df['Release_Date'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # How many type of Category?

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,4))
sns.countplot(df['Category'])
# Out:
# C:\Users\Prajwal Singh\AppData\Roaming\Python\Python310\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot: xlabel='Category', ylabel='count'>

# %% [markdown]
# # Extracing year only and adding a column 'Year'

# %%
df['Year']=df['Release_Date'].dt.year

# %%
df.head(4)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# ...

# %% [markdown]
# # filtering data

# %% [markdown]
# # find the records where category in Movie and year in 2017

# %%
df[(df['Category']=='Movie') & (  df['Year']==2017.0)].head(3)
# Out:
#    Show_Id Category Title      Director  \
# 3       s4    Movie     9   Shane Acker
# 9      s10    Movie  1920  Vikram Bhatt
# 10     s11    Movie  1922  Zak Hilditch
#
#                                                  Cast        Country  \
# 3   Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 9   Rajneesh Duggal, Adah Sharma, Indraneil Sengup...          India
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
#
#    Release_Date Rating Duration  \
# 3    2017-11-16  PG-13   80 min
# 9    2017-12-15  TV-MA  143 min
# 10   2017-10-20  TV-MA  103 min
#
#                                                  Type  \
# 3   Action & Adventure, Independent Movies, Sci-Fi...
# 9      Horror Movies, International Movies, Thrillers
# 10                                  Dramas, Thrillers
#
#                                           Description    Year
# 3   In a postapocalyptic world, rag-doll robots hi...  2017.0
# ...

# %% [markdown]
# # find records where country= "India" and Category='TV Shows'

# %%
df[(df['Category']=='TV Show') & (df['Country']=='India')][['Title','Country','Category']]
# Out:
#                                    Title Country Category
# 86          21 Sarfarosh: Saragarhi 1897   India  TV Show
# 132                            7 (Seven)   India  TV Show
# 340                         Agent Raghav   India  TV Show
# 364                         Akbar Birbal   India  TV Show
# 533                  Anjaan: Rural Myths   India  TV Show
# ...                                  ...     ...      ...
# 6249                The Creative Indians   India  TV Show
# 6400  The Golden Years with Javed Akhtar   India  TV Show
# 6469              The House That Made Me   India  TV Show
# 7294                          Typewriter   India  TV Show
# 7705                     Yeh Meri Family   India  TV Show
#
# [71 rows x 3 columns]

# %% [markdown]
# # Top 10 directors who gave more TV Shows and Movies?

# %%
df['Director'].value_counts().head(10)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Hakan Algül                8
# Name: Director, dtype: int64

# %%
df.head(5)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0   2020-08-14  TV-MA  4 Seasons
# 1   2016-12-23  TV-MA     93 min
# 2   2018-12-20      R     78 min
# 3   2017-11-16  PG-13     80 min
# 4   2020-01-01  PG-13    123 min
#
#                                                 Type  \
# ...

# %% [markdown]
# # Find the records where  category=Movie and type=Comedies or country= United States

# %%
df[(df['Category']=='Movie')&( df['Type']=='Comedies')|  ( df['Country']=='United States')]
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %% [markdown]
# # how many movies/shows 'Tom Cruise ' were  Cast?

# %%
df[df['Cast']=='Tom Cruise']
# this syntax search in exact given value in dataframe
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Year]
# Index: []

# %%
df[df['Cast'].str.contains('Tom Cruise')]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [33], line 1
# ----> 1 df[df['Cast'].str.contains('Tom Cruise')]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:3495, in DataFrame.__getitem__(self, key)
#    3492     return self.where(key)
#    3494 # Do we have a (boolean) 1d indexer?
# -> 3495 if com.is_bool_indexer(key):
#    3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\common.py:144, in is_bool_indexer(key)
#     140     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     141     if lib.infer_dtype(key) == "boolean" and isna(key).any():
# ...

# %% [markdown]
# # dropping the null values

# %%
new_df=df.dropna()

# %%
new_df.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico   2016-12-23
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore   2018-12-20
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description    Year
# 1  After a devastating earthquake hits Mexico Cit...  2016.0
# 2  When an army recruit is found dead, his fellow...  2018.0

# %%
new_df[new_df['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860   2020-01-01      R  189 min  Dramas, Independent Movies
# 5071   2019-07-01      R  134 min      Classic Movies, Dramas
#
#                                             Description    Year
# 3860  Through chance, human action, past history and...  2020.0
# 5071  A fast-talking yuppie is forced to slow down w...  2019.0

# %% [markdown]
# # nunique and unique function

# %%
new_df['Rating'].nunique()
# Out:
# 14

# %%
new_df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-G', 'TV-PG', 'NR', 'PG', 'G',
#        'TV-Y7', 'TV-Y', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
new_df['Rating'].value_counts()
# Out:
# TV-MA       1666
# TV-14       1133
# R            654
# TV-PG        413
# PG-13        375
# PG           238
# TV-G          80
# TV-Y          71
# TV-Y7         69
# NR            62
# G             38
# UR             5
# TV-Y7-FV       3
# NC-17          2
# Name: Rating, dtype: int64

# %% [markdown]
# # how many movies get 'TV-14' rating in Canada country?

# %%
new_df[(new_df['Rating']=='TV-14') & (new_df['Country']=='Canada')  ][['Category','Rating','Country']]
# Out:
#      Category Rating Country
# 34      Movie  TV-14  Canada
# 608     Movie  TV-14  Canada
# 1506    Movie  TV-14  Canada
# 1687  TV Show  TV-14  Canada
# 3713    Movie  TV-14  Canada
# 3956    Movie  TV-14  Canada
# 5336    Movie  TV-14  Canada
# 5393    Movie  TV-14  Canada
# 7025    Movie  TV-14  Canada
# 7041    Movie  TV-14  Canada

# %%
new_df['Year']=new_df['Year'].astype(int)
# Out:
# C:\Users\Prajwal Singh\AppData\Local\Temp\ipykernel_12172\3377176777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Year']=new_df['Year'].astype(int)

# %%
new_df.dtypes
# Out:
# Show_Id                 object
# Category                object
# Title                   object
# Director                object
# Cast                    object
# Country                 object
# Release_Date    datetime64[ns]
# Rating                  object
# Duration                object
# Type                    object
# Description             object
# Year                     int32
# dtype: object

# %% [markdown]
# # how many movies got "R" Rating after 2018

# %%
new_df[(new_df['Rating']=='R') &(new_df['Year']>2018)]
# Out:
#      Show_Id Category               Title                       Director  \
# 7         s8    Movie                 187                 Kevin Reynolds
# 14       s15    Movie                3022                     John Suits
# 65       s66    Movie             13 Sins                   Daniel Stamm
# 68       s69    Movie           14 Blades                     Daniel Lee
# 83       s84    Movie  20th Century Women                     Mike Mills
# ...      ...      ...                 ...                            ...
# 7659   s7658    Movie           Woodshock  Kate Mulleavy, Laura Mulleavy
# 7712   s7711    Movie       Yes, God, Yes                    Karen Maine
# 7738   s7737    Movie         Young Adult                  Jason Reitman
# 7776   s7775    Movie              Zodiac                  David Fincher
# 7780   s7779    Movie          Zombieland                Ruben Fleischer
#
#                                                    Cast  \
# ...

# %% [markdown]
# # checking the maximum duration

# %%
# new_df['Duration'].unique().sort()
#           OR
new_df.Duration.unique()
# Out:
# array(['93 min', '78 min', '80 min', '123 min', '1 Season', '95 min',
#        '119 min', '118 min', '143 min', '103 min', '89 min', '91 min',
#        '149 min', '144 min', '124 min', '110 min', '128 min', '117 min',
#        '100 min', '99 min', '102 min', '104 min', '105 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '87 min', '109 min',
#        '101 min', '90 min', '113 min', '114 min', '130 min', '94 min',
#        '140 min', '135 min', '82 min', '70 min', '92 min', '164 min',
#        '83 min', '116 min', '84 min', '86 min', '120 min', '96 min',
#        '126 min', '75 min', '129 min', '77 min', '137 min', '148 min',
#        '121 min', '122 min', '176 min', '85 min', '22 min', '68 min',
#        '111 min', '29 min', '142 min', '168 min', '59 min', '108 min',
#        '44 min', '26 min', '156 min', '98 min', '57 min', '150 min',
#        '133 min', '115 min', '154 min', '127 min', '146 min', '136 min',
# ...

# %% [markdown]
# # str.spilit function

# %%
new_df[['minutes' , 'units']]= new_df['Duration'].str.split(' ', expand=True)
# Out:
# C:\Users\Prajwal Singh\AppData\Local\Temp\ipykernel_12172\3074461815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[['minutes' , 'units']]= new_df['Duration'].str.split(' ', expand=True)
# C:\Users\Prajwal Singh\AppData\Local\Temp\ipykernel_12172\3074461815.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df[['minutes' , 'units']]= new_df['Duration'].str.split(' ', expand=True)

# %%
new_df.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   Release_Date Rating Duration  \
# 1   2016-12-23  TV-MA   93 min
# 2   2018-12-20      R   78 min
# 3   2017-11-16  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description  Year minutes units
# 1  After a devastating earthquake hits Mexico Cit...  2016      93   min
# ...

# %% [markdown]
# # changing the datatype of column

# %%
new_df['minutes']= new_df['minutes'].astype(int)
# Out:
# C:\Users\Prajwal Singh\AppData\Local\Temp\ipykernel_12172\21118808.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['minutes']= new_df['minutes'].astype(int)

# %%
new_df['minutes'].dtypes
# Out:
# dtype('int32')

# %% [markdown]
# # getting maximun duration movie shows

# %%
new_df['minutes'].max()
# Out:
# 253

# %%
# minumum duration movies or shows
new_df['minutes'].min()
# Out:
# 1

# %% [markdown]
# # which individual country has maximun number of tv shows

# %%
new_df['Country'].value_counts()
# Out:
# United States                                                   1654
# India                                                            832
# United Kingdom                                                   174
# Canada                                                           104
# Egypt                                                             87
#                                                                 ...
# United Kingdom, Canada, United States, Cayman Islands              1
# Netherlands, Belgium                                               1
# United Kingdom, Denmark, Canada, Croatia                           1
# Thailand, United States                                            1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: Country, Length: 544, dtype: int64

# %%
new_df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#   Release_Date Rating  Duration  \
# 1   2016-12-23  TV-MA    93 min
# 2   2018-12-20      R    78 min
# 3   2017-11-16  PG-13    80 min
# 4   2020-01-01  PG-13   123 min
# 5   2017-07-01  TV-MA  1 Season
#
#                                                 Type  \
# ...

# %% [markdown]
# # Creating new dataframe

# %%
TV_Show= new_df[new_df['Category']=='TV Show']

# %%
TV_Show.head(4)
# Out:
#     Show_Id Category            Title       Director  \
# 5        s6  TV Show               46    Serdar Akar
# 132    s133  TV Show        7 (Seven)    Nizar Shafi
# 218    s219  TV Show  A Queen Is Born   Carla Barros
# 260    s261  TV Show         A.I.C.O.  Kazuya Murata
#
#                                                   Cast Country Release_Date  \
# 5    Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...  Turkey   2017-07-01
# 132  Rahman, Havish, Regina Cassandra, Nandita Swet...   India   2019-07-30
# 218                      Gloria Groove, Alexia Twister  Brazil   2020-11-11
# 260  Haruka Shiraishi, Yusuke Kobayashi, Makoto Fur...   Japan   2018-03-09
#
#     Rating  Duration                                             Type  \
# 5    TV-MA  1 Season  International TV Shows, TV Dramas, TV Mysteries
# 132  TV-14  1 Season                                         TV Shows
# 218  TV-14  1 Season               International TV Shows, Reality TV
# ...

# %%
TV_Show.shape
# Out:
# (136, 14)

# %%
TV_Show.Country.value_counts().head(1)
# Out:
# United States    27
# Name: Country, dtype: int64

# %% [markdown]
# # sorting dataset accordind to Country

# %%
new_df.sort_values(by='Country', ascending= False)
new_df.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#   Release_Date Rating Duration  \
# 1   2016-12-23  TV-MA   93 min
# 2   2018-12-20      R   78 min
# 3   2017-11-16  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description  Year  minutes units
# 1  After a devastating earthquake hits Mexico Cit...  2016       93   min
# ...

# %%
# category =Movie  and type = drama
new_df[(new_df['Category']=='Movie')&(new_df['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
# category = tv shows and type = kid rv
new_df[(new_df['Category']=='TV Show')&(new_df['Country']=='United States')]
# Out:
#      Show_Id Category                                              Title  \
# 578     s579  TV Show                       Ari Shaffir: Double Negative
# 584     s585  TV Show                                              Arrow
# 1470   s1471  TV Show                   Comedians in Cars Getting Coffee
# 1629   s1630  TV Show                                     Dave Chappelle
# 1630   s1631  TV Show   Dave Chappelle: Equanimity & The Bird Revelation
# 1647   s1648  TV Show                           DC's Legends of Tomorrow
# 1981   s1982  TV Show                         Ellen DeGeneres: Relatable
# 2196   s2197  TV Show                                     Five Came Back
# 2360   s2361  TV Show                      Garth Brooks: The Road I’m On
# 2504   s2505  TV Show                                             Gotham
# 2697   s2698  TV Show                                      Hemlock Grove
# 2832   s2833  TV Show                                     House of Cards
# ...

# %% [markdown]
# # Combining both upper condition in together

# %%
new_df[((new_df['Category']=='TV Show')&(new_df['Country']=='United States'))|(new_df['Category']=='Movie')&(new_df['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title            Director  \
# 4         s5    Movie                          21      Robert Luketic
# 7         s8    Movie                         187      Kevin Reynolds
# 170     s171    Movie                A Family Man       Mark Williams
# 232     s233    Movie  A Stoning in Fulham County       Larry Elikann
# 295     s296    Movie          Across Grace Alley       Ralph Macchio
# ...      ...      ...                         ...                 ...
# 7422   s7421    Movie                     Villain    Philip Barantini
# 7449   s7448    Movie                         VS.            Ed Lilly
# 7465   s7464    Movie                   Wakefield       Robin Swicord
# 7480   s7479    Movie                   War Horse    Steven Spielberg
# 7723   s7722  TV Show                         You  Lee Toland Krieger
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...
